# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "Resources/Mouse_metadata.csv"
study_results_path = "Resources/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
study_data_complete = pd.merge(study_results, mouse_metadata, how="left", on="Mouse ID")

# Display the data table for preview
study_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
len(study_data_complete["Mouse ID"].unique())
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicateMice = study_data_complete["Mouse ID"].value_counts().to_frame()
duplicateMice = duplicateMice.rename(columns={"Mouse ID": "Counts of Mouse ID"})
duplicateMice.head()
# Out:
#       Counts of Mouse ID
# g989                  13
# w350                  10
# j119                  10
# j296                  10
# t451                  10

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicateMiceDF = study_data_complete.loc[study_data_complete["Mouse ID"]== "g989"]
duplicateMiceDF

# set the index to the mouse ID
duplicateMiceDF.set_index("Mouse ID", drop=True, append=False, inplace=True, verify_integrity=False)
duplicateMiceDF

# check the mouse data for ID
# Out:
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# Mouse ID
# g989              0           45.000000                 0     Propriva
# g989              0           45.000000                 0     Propriva
# g989              5           48.786801                 0     Propriva
# g989              5           47.570392                 0     Propriva
# g989             10           51.745156                 0     Propriva
# g989             10           49.880528                 0     Propriva
# g989             15           51.325852                 1     Propriva
# g989             15           53.442020                 0     Propriva
# g989             20           55.326122                 1     Propriva
# g989             20           54.657650                 1     Propriva
# g989             25           56.045564                 1     Propriva
# g989             30           59.082294                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleanStudy = study_data_complete[study_data_complete["Mouse ID"].isin(duplicateMiceDF)==False]
cleanStudy.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
len(cleanStudy["Mouse ID"].unique())
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

# series variable to hold Tumor Volume Data grouped by Drug Regimen

# variable to hold the Mean Tumor Volume Data Grouped by Drug Regimen


# variable to hold median Tumor Volume Data Grouped by Drug Regimen


# variable to hold the Tumor Volume Variance Data Grouped by Drug Regimen


# variable to hold the Tumor Volume Standard Deviation Data Grouped by Drug Regimen


# variable to hold the Tumor Volume SEM Data Grouped by Drug Regimen


# Convert to DataFrame

# Preview DataFrame

# %%
means = cleanStudy.groupby("Drug Regimen").mean()["Tumor Volume (mm3)"]
medians = cleanStudy.groupby("Drug Regimen").median()["Tumor Volume (mm3)"]
variances = cleanStudy.groupby("Drug Regimen").var()["Tumor Volume (mm3)"]
stdev = cleanStudy.groupby("Drug Regimen").std()["Tumor Volume (mm3)"]
sems = cleanStudy.groupby("Drug Regimen").sem()["Tumor Volume (mm3)"]

summaryTable = pd.DataFrame({
    "Mean Tumor Volume": means,
    "Median Tumor Volume": medians,
    "Tumor Volume Variance": variances,
    "Tumor Volume Stdev": stdev,
    "Tumor Volume SEM": sems
})

summaryTable
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Stdev  Tumor Volume SEM
# Drug Regimen
# Capomulin               4.994774          0.329346
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
summary_table= cleanStudy.groupby("Drug Regimen").agg({
    "Tumor Volume (mm3)":["mean", "median", "var", "std", "sem"]
})
summary_table
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
cleanStudy
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

# list of unique drug regimens

# drug regimen as x-axis values for plotting

# drop all duplicate mice


# get mice counts per drug
counts = cleanStudy["Drug Regimen"].value_counts()
counts.plot(kind='bar', color='green')
plt.xlabel("Drug Regimen")
plt.ylabel("Mice Count")
plt.title("Mouse Counts by Drug Regimen")
plt.legend(["Drug Regimen"],loc="best")
plt.show()

# %%
# plot the mouse counts for each drug using pandas

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
# plot the bar graph of mice count per drug regimen
plt.bar(counts.index.values,counts.values,color='green')
plt.xlabel("Drug Regimen")
plt.ylabel("Mice Count")
plt.title("Mouse Counts by Drug Regimen")
plt.legend(["Drug Regimen"],loc="best")
plt.show()

# %%
counts = cleanStudy["Sex"].value_counts()
counts
# Out:
# Male      958
# Female    935
# Name: Sex, dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
counts.plot(kind='pie', autopct="%1.1f%%")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(counts.values, labels=counts.index.values, autopct="%1.1f%%")
plt.ylabel("Gender")
plt.legend(["Male","Female"],loc="upper right")

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Start by getting the last (greatest) timepoint for each mouse
lastTumorVolume = cleanStudy.groupby("Mouse ID")["Timepoint"].max()
lastTumorVolume = lastTumorVolume.reset_index()

#Merge this group df wiht the original dataframe to get the tumor volume at the last time passed
cleanMergedDF = lastTumorVolume.merge(cleanStudy, on=["Mouse ID","Timepoint"],how="left")

test = cleanMergedDF.sort_values(['Timepoint'], ascending=[True], inplace = True)
cleanMergedDF.set_index(["Mouse ID"], drop=True, append=False, inplace=True, verify_integrity=False)


cleanMergedDF = cleanMergedDF.loc[cleanMergedDF['Drug Regimen'].isin(['Capomulin', 'Ramicane', 
                                                                                  'Infubinol', 'Ceftamin'])]

cleanMergedDF

# show all rows of data
# Out:
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# Mouse ID
# t573              0           45.000000                 0     Ceftamin
# u153              0           45.000000                 0     Ceftamin
# b447              0           45.000000                 0     Ceftamin
# x226              0           45.000000                 0     Ceftamin
# m756              5           47.010364                 1    Infubinol
# ...             ...                 ...               ...          ...
# k403             45           22.050126                 1     Ramicane
# k483             45           66.196912                 3    Infubinol
# l471             45           67.748662                 1     Ceftamin
# l509             45           41.483008                 3    Capomulin
# i177             45           33.562402                 3     Ramicane
#
#              Sex  Age_months  Weight (g)
# Mouse ID
# t573      Female          15          27
# ...

# %%
# Start by getting the last (greatest) timepoint for each mouse
lastTumorVolume = cleanStudy.groupby("Mouse ID")["Timepoint"].max()
lastTumorVolume = lastTumorVolume.reset_index()
lastTumorVolume.head()
# Out:
#   Mouse ID  Timepoint
# 0     a203         45
# 1     a251         45
# 2     a262         45
# 3     a275         45
# 4     a366         30

# %%
print(cleanMergedDF["Drug Regimen"].unique())
# Out:
# ['Ceftamin' 'Infubinol' 'Ramicane' 'Capomulin']

# %%
# tumor volumes for each Drug Regimen
cleanSummary = cleanMergedDF.drop(["Metastatic Sites","Timepoint","Sex","Age_months", "Weight (g)"], axis=1)
cleanSummary.head()
# Out:
#           Tumor Volume (mm3) Drug Regimen
# Mouse ID
# t573               45.000000     Ceftamin
# u153               45.000000     Ceftamin
# b447               45.000000     Ceftamin
# x226               45.000000     Ceftamin
# m756               47.010364    Infubinol

# %%
# Put treatments into a list for for loop (and later for plot labels)
#set drugs to be analyzed, colors for the plots, and markers
treatments_list = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumorData = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for t in treatments_list:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    finalTumorCount = cleanMergedDF.loc[cleanMergedDF["Drug Regimen"]==t, "Tumor Volume (mm3)"]
    
    # add subset
    tumorData.append(finalTumorCount)
    
    # Determine outliers using upper and lower bounds
    quartiles = finalTumorCount.quantile([0.25, 0.5, 0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    lowerbound = lowerq - (1.5 * iqr)
    upperbound = upperq + (1.5 * iqr)
    outliers = finalTumorCount.loc[(finalTumorCount < lowerbound) | (finalTumorCount > upperbound)]
    print(f"{t}'s potential outliers: \n{outliers}")
# Out:
# Capomulin's potential outliers:
# Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers:
# Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers:
# Mouse ID
# c326    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers:
# Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
orange_out = dict(markerfacecolor = 'red', markersize=12)
plt.boxplot(tumorData, labels = treatments_list, flierprops=orange_out)
plt.ylabel("Final Tumor Volume (mm3)")
plt.xlabel("Drug Regimen")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# generate a table of all Mice filtered out by the Capomulin regimen
capomulinTable = cleanStudy.loc[cleanStudy["Drug Regimen"]=="Capomulin"]
capomulinTable.drop(labels=None, axis=0, index = 0)
capomulinTable.head()
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       b128          0                45.0                 0    Capomulin
# 226     j246          0                45.0                 0    Capomulin
# 227     r554          0                45.0                 0    Capomulin
# 228     s185          0                45.0                 0    Capomulin
# 229     b742          0                45.0                 0    Capomulin
#
#         Sex  Age_months  Weight (g)
# 0    Female           9          22
# 226  Female          21          21
# 227  Female           8          17
# 228  Female           3          17
# 229    Male           7          21

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

#change index to mouse ID 

#remove other mouse IDs so only s185 shows
miceData = capomulinTable.loc[capomulinTable["Mouse ID"]=="s185"]
plt.plot(miceData["Timepoint"], miceData["Tumor Volume (mm3)"])
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3) of Mouse s185")
plt.show()

#set the x-axis equal to the Timepoint and y-axis to Tumor Volume

# %%
capomulinAverage = capomulinTable.groupby("Mouse ID").mean()
capomulinAverage.head()
# Out:
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites  Age_months  \
# Mouse ID
# b128           22.5           41.963636               0.7         9.0
# b742           22.5           40.083699               0.0         7.0
# f966           10.0           36.505973               0.0        16.0
# g288           22.5           41.990097               0.8         3.0
# g316           22.5           44.613344               1.0        22.0
#
#           Weight (g)
# Mouse ID
# b128            22.0
# b742            21.0
# f966            17.0
# g288            19.0
# g316            22.0

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
# group by mouse ID to find average tumor volume


# establish x-axis value for the weight of the mice


# produce scatter plot of the data
plt.scatter(capomulinAverage["Weight (g)"], capomulinAverage["Tumor Volume (mm3)"])
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Tumor Volume Average vs Mouse Weight")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
#establish x and y values and find St. Pearson Correlation Coefficient for Mouse Weight and Tumor Volume Avg
correlation = round(st.pearsonr(capomulinAverage["Weight (g)"], capomulinAverage["Tumor Volume (mm3)"])[0],2)
print(f"The correlation between mouse weight and the average tumor volume is {correlation:.2f}")
print("This correlation shows a positive relationship between mouse weight and the average tumor volume")

#print St. Pearson Correlation Coefficient

# establish linear regression values
model = st.linregress(capomulinAverage["Weight (g)"], capomulinAverage["Tumor Volume (mm3)"])
print(model)

yValues= capomulinAverage["Weight (g)"] *model[0] + model[1] # y=mx+b
# scatter plot of the data
plt.scatter(capomulinAverage["Weight (g)"], capomulinAverage["Tumor Volume (mm3)"])
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Tumor Volume Average vs Mouse Weight")

# linear regression line 
plt.plot(capomulinAverage["Weight (g)"], yValues, color='red')
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
# This correlation shows a positive relationship between mouse weight and the average tumor volume
# LinregressResult(slope=0.9544396890241045, intercept=21.552160532685015, rvalue=0.8419363424694718, pvalue=1.3225722434712642e-07, stderr=0.12754359033201337, intercept_stderr=2.5909876867683486)
